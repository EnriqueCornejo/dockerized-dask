# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
test = np.load('/temp/0_0.npy')

# %%
test.shape
# Out:
# (10950, 72, 72)

# %%
test[:, 50, 50]
# Out:
# array([  1.83077390e-07,   1.24364635e-06,   2.04844866e-07, ...,
#          0.00000000e+00,   0.00000000e+00,   8.06035700e-07])

# %%
plt.figure(figsize=(20, 10))
plt.plot(test[:, 50, 50])
