# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from dask.dot import dot_graph
import itertools
import logging
import netCDF4
import numpy
import dask.array as da
from dask import delayed
import time
from dask.distributed import Client
from urllib import request


client = Client('scheduler:8786')
# client = Client(processes=False)
client.ncores()

download_location = '/temp'
data_url = 'http://172.22.0.1:8910'
max_download_attempts = 5

all_models = ['ACCESS1-0', 'BNU-ESM', 'CCSM4', 'CESM1-BGC', 'CNRM-CM5', 'CSIRO-Mk3-6-0', 'CanESM2', 'GFDL-CM3', 'GFDL-ESM2G', 'GFDL-ESM2M', 'IPSL-CM5A-LR', 'IPSL-CM5A-MR', 'MIROC-ESM-CHEM', 'MIROC-ESM', 'MIROC5', 'MPI-ESM-LR', 'MPI-ESM-MR', 'MRI-CGCM3', 'NorESM1-M', 'bcc-csm1-1', 'inmcm4']
all_models = ['ACCESS1-0'] 
all_vars = ['tasmax', 'pr']
all_years = {
     'historical': list(range(1971, 1973))
}

def get_dataset_url(variable, scenario, model, year, prefix = data_url):
    prefix_filename = '/'.join([prefix, 'NEX-GDDP', 'BCSD', scenario, 'day', 'atmos', variable, 'r1i1p1', 'v1.0'])
    # prefix_filename = data_url + '/data'
    filename = '_'.join([variable, 'day', 'BCSD', scenario, 'r1i1p1', model, str(year) + '.nc'])
    url = '/'.join([prefix_filename, filename])
    return url

def get_context(year, **kwargs):
    variables = [kwargs.get('variable')] if kwargs.get('variable') else all_vars
    scenarios = ['historical']
    models = [kwargs.get('model')] if kwargs.get('model') else all_models
    outlist = []
    combinations = list(itertools.product(variables, scenarios, models))
    result = list(map(lambda comb: [ *comb, year ], combinations))
    return result

def get_year_ensemble(year, variable = 'tasmax'):
    context = get_context(year, variable = variable)
    datasets = list(map(lambda x: str(get_dataset_url(*x)), context))
    return datasets

def to_dataset(filename):
    return netCDF4.Dataset(filename)

def download_file(url):
    print("url: " + url)
    attempts = 0
    success = False
    filename = ""
    while attempts < max_download_attempts and not success:
        time.sleep(2 ** attempts)
        filename = '/'.join([download_location, str(url.split('/')[-1])])
        print("Downloading file at " + filename)
        u = request.urlopen(url)
        f = open(filename, 'wb')
        f.write(u.read())
        f.close()
        success = True
        break
    return filename

# %%
client.ncores()
# Out:
# {'tcp://172.22.0.2:46199': 2,
#  'tcp://172.22.0.3:37943': 2,
#  'tcp://172.22.0.4:45277': 2,
#  'tcp://172.22.0.7:39813': 2}

# %%
datasets_tasmax = list(map(get_year_ensemble, all_years['historical']))
datasets_pr = list(map(lambda x : get_year_ensemble(x, variable = 'pr'), all_years['historical']))
datasets_tasmax
# Out:
# [['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1971.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1972.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1973.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1974.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1975.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1976.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1977.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1978.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1979.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1980.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1981.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1982.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1983.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1984.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1985.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1986.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1987.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1988.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1989.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1990.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1991.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1992.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1993.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1994.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1995.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1996.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1997.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1998.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1999.nc'],
#  ['http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_2000.nc']]

# %%
dsets = []
da_dsets = []
for row in datasets_tasmax:
    print("Processing year")
    fnames = list(map(download_file, row))
    datasets_year = list(map(lambda dset: netCDF4.Dataset(dset), fnames))
    dsets.append(datasets_year)
    
    dask_dsets_year = map(lambda dset: da.from_array(dset['tasmax'], chunks=(366, 120, 120)), datasets_year)
    da_dsets.append(list(dask_dsets_year))

da_dsets
# Out:
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1971.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1971.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1972.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1972.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1973.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1973.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1974.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1974.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1975.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1975.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1976.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1976.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1977.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1977.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1978.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1978.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1979.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1979.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1980.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1980.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1981.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1981.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1982.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1982.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1983.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1983.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1984.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1984.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1985.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1985.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1986.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1986.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1987.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1987.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1988.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1988.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1989.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1989.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1990.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1990.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1991.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1991.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1992.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1992.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1993.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1993.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1994.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1994.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1995.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1995.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1996.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1996.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1997.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1997.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1998.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1998.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1999.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_1999.nc
# Processing year
# url: http://172.22.0.1:8910/NEX-GDDP/BCSD/historical/day/atmos/tasmax/r1i1p1/v1.0/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_2000.nc
# Downloading file at /temp/tasmax_day_BCSD_historical_r1i1p1_ACCESS1-0_2000.nc
# [[dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>],
#  [dask.array<array, shape=(366, 720, 1440), dtype=float32, chunksize=(366, 120, 120)>]]

# %%
da_dsets = [row[0] for row in da_dsets]
da_dsets[0]
# Out:
# dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>

# %%
same_length_dsets = list(filter(lambda dset: dset.chunks[0][0] == 365, da_dsets))
same_length_dsets
# Out:
# [dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>,
#  dask.array<array, shape=(365, 720, 1440), dtype=float32, chunksize=(365, 120, 120)>]

# %%
# To stack the datasets along a new axis:
avg_stack = da.stack(same_length_dsets, axis = 0)
print(avg_stack)

@delayed
def custom_average(a, **kwargs):
    return numpy.mean(a, **kwargs)

model_averages = custom_average(avg_stack, axis = 0).compute()
# Out:
# dask.array<stack, shape=(22, 365, 720, 1440), dtype=float32, chunksize=(1, 365, 120, 120)>

# %%
# To concatenate dask arrays
stack = da.concatenate(da_dsets, axis = 0)
stack_rechunked = stack.rechunk((731, 120, 120))

stack_rechunked
# Out:
# dask.array<rechunk-merge, shape=(731, 720, 1440), dtype=float32, chunksize=(731, 120, 120)>

# %%
@delayed
def custom_percentile(a, q = 99, **kwargs):
    return numpy.percentile(a, q, **kwargs)

@delayed
def custom_nanpercentile(a, q = 99, **kwargs):
    return numpy.nanpercentile(a, q, **kwargs)


# custom_percentile(da.from_array(numpy.arange(1000000).reshape(100, 100, 100), chunks=(10))).compute()
custom_percentile(da.from_array(numpy.arange(1000000).reshape(100, 100, 100), chunks=(10)), axis=2).compute()
# Out:
# array([[  9.80100000e+01,   1.98010000e+02,   2.98010000e+02, ...,
#           9.79801000e+03,   9.89801000e+03,   9.99801000e+03],
#        [  1.00980100e+04,   1.01980100e+04,   1.02980100e+04, ...,
#           1.97980100e+04,   1.98980100e+04,   1.99980100e+04],
#        [  2.00980100e+04,   2.01980100e+04,   2.02980100e+04, ...,
#           2.97980100e+04,   2.98980100e+04,   2.99980100e+04],
#        ...,
#        [  9.70098010e+05,   9.70198010e+05,   9.70298010e+05, ...,
#           9.79798010e+05,   9.79898010e+05,   9.79998010e+05],
#        [  9.80098010e+05,   9.80198010e+05,   9.80298010e+05, ...,
#           9.89798010e+05,   9.89898010e+05,   9.89998010e+05],
#        [  9.90098010e+05,   9.90198010e+05,   9.90298010e+05, ...,
#           9.99798010e+05,   9.99898010e+05,   9.99998010e+05]])

# %%
# Running some speed tests
op = custom_percentile(stack_rechunked, axis = 0)
# %timeit res = op.compute()
# Out:
# 1min 41s ± 839 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
op = custom_nanpercentile(stack_rechunked, axis = 0)
# %timeit res = op.compute()
# Out:
# 4min 55s ± 1.07 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
raster_percentile = custom_percentile(stack_rechunked, axis = 0).compute()
raster_nan_percentile = custom_nanpercentile(stack_rechunked, axis = 0).compute()

# %%
raster_percentile = custom_percentile(stack_rechunked, axis = 0).compute()

# %%
raster_percentile.shape
# Out:
# (720, 1440)

# %%
mask = (raster_percentile == numpy.amax(raster_percentile))
mask
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
# I guess that percentile is enough

# raster_percentile is read only
raster_percentile_copy = raster_percentile.copy()
# beware the NaNs
raster_percentile_copy[mask] = numpy.nan
ptp, amax = (numpy.nanmax(raster_percentile_copy) - numpy.nanmin(raster_percentile_copy), numpy.nanmax(raster_percentile_copy))
norm_0_1 = (raster_percentile_copy - amax) / -ptp
norm_0_1
plt.figure(figsize = (12, 24))
plt.imshow(norm_0_1, origin='lower', cmap='coolwarm_r')
